# %% [markdown]
# <a href="https://colab.research.google.com/github/tafarello01/AULA-GIT/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Primeiro programa com POO - Divisão Inteira

x = 27.9
y = 2

resultado = x/y

print(resultado)
# Out:
# 13.95
